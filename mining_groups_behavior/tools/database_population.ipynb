# %%
from datetime import datetime
from datetime import timedelta
from random import randint, choice

import pandas as pd
from sqlalchemy import create_engine


# engine = create_engine("postgres://miningAgent:@localhost/QeNoBi")
engine = create_engine("postgres://saukyezhotsmbe:ad54b3453dc396906a14968e1adea93336701b154a89e83b9b11a7bc71676f8c@ec2-34-240-75-196.eu-west-1.compute.amazonaws.com:5432/degdmlpglf9frn")

# %%
engine = create_engine("postgres://saukyezhotsmbe:ad54b3453dc396906a14968e1adea93336701b154a89e83b9b11a7bc71676f8c@ec2-34-240-75-196.eu-west-1.compute.amazonaws.com:5432/degdmlpglf9frn")
# engine = create_engine("postgres://miningAgent:@localhost/QeNoBi")

# %%
# !ls /home/abdelouahab/Q*
# Out:
# /home/abdelouahab/QeNoBi_public_customers.csv
# /home/abdelouahab/QeNoBi_public_stations.csv
# /home/abdelouahab/QeNoBi_public_transactions.csv
#
# /home/abdelouahab/QeNoBi:
# bin  etc  include  lib	share

# %%
# !pip install tqd
# Out:
# Collecting tqdM
#   Downloading tqdm-4.59.0-py2.py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 301 kB/s eta 0:00:01
# Installing collected packages: tqdM
# Successfully installed tqdM-4.59.0

# %%
df = pd.read_csv("/home/abdelouahab/QeNoBi_public_customers.csv")
from tqdm import tqdm
for i in tqdm(range(1000,df.shape[0],1000)):
    df[max(1000-i,0):i].to_sql("customers",if_exists="append",con=engine,method="multi")
# Out:
#   2%|▏         | 21/1140 [06:17<5:35:03, 17.97s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-1c5bb88b2ceb> in <module>
#       2 from tqdm import tqdm
#       3 for i in tqdm(range(1000,df.shape[0],1000)):
# ----> 4     df[max(1000-i,0):i].to_sql("customers",if_exists="append",con=engine,method="multi")
#       5
#       6
#
# ~/QeNoBi/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2776         from pandas.io import sql
#    2777
# -> 2778         sql.to_sql(
#    2779             self,
#    2780             name,
#
# ~/QeNoBi/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     588         )
#     589
# --> 590     pandas_sql.to_sql(
#     591         frame,
#     592         name,
#
# ~/QeNoBi/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1395
#    1396         try:
# -> 1397             table.insert(chunksize, method=method)
#    1398         except exc.SQLAlchemyError as err:
#    1399             # GH34431
#
# ~/QeNoBi/lib/python3.8/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     829
#     830                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 831                 exec_insert(conn, keys, chunk_iter)
#     832
#     833     def _query_iterator(
#
# ~/QeNoBi/lib/python3.8/site-packages/pandas/io/sql.py in _execute_insert_multi(self, conn, keys, data_iter)
#     757         """
#     758         data = [dict(zip(keys, row)) for row in data_iter]
# --> 759         conn.execute(self.table.insert(data))
#     760
#     761     def insert_data(self):
#
# ~/QeNoBi/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1012             )
#    1013         else:
# -> 1014             return meth(self, multiparams, params)
#    1015
#    1016     def _execute_function(self, func, multiparams, params):
#
# ~/QeNoBi/lib/python3.8/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~/QeNoBi/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1125             )
#    1126
# -> 1127         ret = self._execute_context(
#    1128             dialect,
#    1129             dialect.execution_ctx_cls._init_compiled,
#
# ~/QeNoBi/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315
#    1316         except BaseException as e:
# -> 1317             self._handle_dbapi_exception(
#    1318                 e, statement, parameters, cursor, context
#    1319             )
#
# ~/QeNoBi/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1513                 )
#    1514             else:
# -> 1515                 util.raise_(exc_info[1], with_traceback=exc_info[2])
#    1516
#    1517         finally:
#
# ~/QeNoBi/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~/QeNoBi/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                             break
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#    1279                     )
#
# ~/QeNoBi/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# ~/QeNoBi/lib/python3.8/encodings/utf_8.py in decode(input, errors)
#      13 encode = codecs.utf_8_encode
#      14
# ---> 15 def decode(input, errors='strict'):
#      16     return codecs.utf_8_decode(input, errors, True)
#      17
#
# KeyboardInterrupt:

# %%
df = pd.read_csv("/home/abdelouahab/QeNoBi_public_transactions.csv")
from tqdm import tqdm
for i in tqdm(range(1000,df.shape[0],1000)):
    df[max(1000-i,0):i].to_sql("transactions",if_exists="append",con=engine,method="multi",index=False)
# Out:
#   0%|          | 0/147 [00:08<?, ?it/s]
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~/QeNoBi/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#
# ~/QeNoBi/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# UndefinedColumn: column "2018-12-13" of relation "transactions" does not exist
# LINE 1: INSERT INTO transactions ("2018-12-13", "NF07821812802851812...
#                                   ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-11-c303a419fc5b> in <module>
#       2 from tqdm import tqdm
#       3 for i in tqdm(range(1000,df.shape[0],1000)):
# ----> 4     df[max(1000-i,0):i].to_sql("transactions",if_exists="append",con=engine,method="multi",index=False)
#
# ~/QeNoBi/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2776         from pandas.io import sql
#    2777
# -> 2778         sql.to_sql(
#    2779             self,
#    2780             name,
#
# ~/QeNoBi/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     588         )
#     589
# --> 590     pandas_sql.to_sql(
#     591         frame,
#     592         name,
#
# ~/QeNoBi/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1403                 raise ValueError("inf cannot be used with MySQL") from err
#    1404             else:
# -> 1405                 raise err
#    1406
#    1407         if not name.isdigit() and not name.islower():
#
# ~/QeNoBi/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1395
#    1396         try:
# -> 1397             table.insert(chunksize, method=method)
#    1398         except exc.SQLAlchemyError as err:
#    1399             # GH34431
#
# ~/QeNoBi/lib/python3.8/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     829
#     830                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 831                 exec_insert(conn, keys, chunk_iter)
#     832
#     833     def _query_iterator(
#
# ~/QeNoBi/lib/python3.8/site-packages/pandas/io/sql.py in _execute_insert_multi(self, conn, keys, data_iter)
#     757         """
#     758         data = [dict(zip(keys, row)) for row in data_iter]
# --> 759         conn.execute(self.table.insert(data))
#     760
#     761     def insert_data(self):
#
# ~/QeNoBi/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1012             )
#    1013         else:
# -> 1014             return meth(self, multiparams, params)
#    1015
#    1016     def _execute_function(self, func, multiparams, params):
#
# ~/QeNoBi/lib/python3.8/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~/QeNoBi/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1125             )
#    1126
# -> 1127         ret = self._execute_context(
#    1128             dialect,
#    1129             dialect.execution_ctx_cls._init_compiled,
#
# ~/QeNoBi/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315
#    1316         except BaseException as e:
# -> 1317             self._handle_dbapi_exception(
#    1318                 e, statement, parameters, cursor, context
#    1319             )
#
# ~/QeNoBi/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1510             elif should_wrap:
# -> 1511                 util.raise_(
#    1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#
# ~/QeNoBi/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~/QeNoBi/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                             break
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#    1279                     )
#
# ~/QeNoBi/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column
180327132259', '2018-12-13 19:27:25_m7': '2018-03-27 13:22:59', 'NF078218_m7': 'NF078002', '193943_m7': 220201, '3656_m7': 2571, '1_m7': '8,4', 'M_m7': 'F', '>65_m7': '50-65', '78_m7': 78, '78.1_m7': 78, 'COCO_m7': 'CODO', '2018-12-13 19:27:25.1_m7': '2018-03-27 13:22:59', 'Retail_m7': 'Retail', '2018-12-13_m8': '2018-03-12', 'NF0782181280285181213192725_m8': 'NF0780021183719180312150404', '2018-12-13 19:27:25_m8': '2018-03-12 15:04:04', 'NF078218_m8': 'NF078002', '193943_m8': 220201, '3656_m8': 2571, '1_m8': '8,4', 'M_m8': 'F', '>65_m8': '50-65', '78_m8': 78, '78.1_m8': 78, 'COCO_m8': 'CODO', '2018-12-13 19:27:25.1_m8': '2018-03-12 15:04:04', 'Retail_m8': 'Retail', '2018-12-13_m9': '2018-02-15', 'NF0782181280285181213192725_m9': 'NF0780029700691180215165016', '2018-12-13 19:27:25_m9': '2018-02-15 16:54:48', 'NF078218_m9': 'NF078002', '193943_m9': 220201, '3656_m9': 3571, '1_m9': '24,9', 'M_m9': 'F', '>65_m9': '50-65', '78_m9': 78, '78.1_m9': 78, 'COCO_m9': 'CODO', '2018-12-13 19:27:25.1_m9': '2018-02-15 16:54:48', 'Retail_m9': 'Retail', '2018-12-13_m10': '2018-02-15', 'NF0782181280285181213192725_m10': 'NF0780029700691180215165016', '2018-12-13 19:27:25_m10': '2018-02-15 16:54:48', 'NF078218_m10': 'NF078002', '193943_m10': 220201, '3656_m10': 2594, '1_m10': '9 ...
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
df = pd.read_csv("/home/abdelouahab/QeNoBi_public_stations.csv")
from tqdm import tqdm
for i in tqdm(range(1000,df.shape[0],1000)):
    df[max(1000-i,0):i].to_sql("stations",if_exists="append",con=engine,method="multi")

# %%
engine.execute("""   delete from "customers" where 1=1  """)

# %%
engine.execute("""   delete from "transactions" where 1=1  """)

# %%
df
# Out:
#         2018-12-13  NF0782181280285181213192725  2018-12-13 19:27:25  \
# 0       2018-01-09  NF0333001209287180109150501  2018-01-09 15:05:01
# 1       2018-10-14  NF0781981101220181014152522  2018-10-14 15:26:42
# 2       2018-02-20  NF0062741179238180220172306  2018-02-20 17:23:06
# 3       2018-11-20  NF0780021166918181120202421  2018-11-20 20:24:21
# 4       2018-11-12  NF0780021164260181112162620  2018-11-12 16:26:20
# ...            ...                          ...                  ...
# 147415  2019-06-14  NF0594969700690190614132821  2019-06-14 13:30:44
# 147416  2019-06-03  NF0801881193100190603110518  2019-06-03 11:05:18
# 147417  2019-06-03  NF0801881193100190603110518  2019-06-03 11:05:18
# 147418  2019-06-03  NF0801881193100190603110518  2019-06-03 11:05:18
# 147419  2018-04-07  NF0407761154191180407115633  2018-04-07 11:57:23
#
#         NF078218   193943  3656     1  M    >65  78  78.1  COCO  \
# 0       NF033300   602830  3616     1  M    >65  33    33  CODO
# 1       NF078198   745446  3598     7  M    <35  78    78  CODO
# 2       NF006274   374337  3598     7  M    <35   6     6  CODO
# 3       NF078002   350541  2614     3  M  50-65  78    78  CODO
# 4       NF078002   220201  3598     7  F  50-65  78    78  CODO
# ...          ...      ...   ...   ... ..    ...  ..   ...   ...
# 147415  NF059496  1211596  2599   5,9  M    <35  59    59  CODO
# 147416  NF080188   700783  3565  18,5  M  35-49  80    80  CODO
# 147417  NF080188   700783  3565  18,5  M  35-49  80    80  CODO
# 147418  NF080188   700783  3565  18,5  M  35-49  80    80  CODO
# 147419  NF040776   105149  3598     7  M  50-65  40    40  DODO
#
#        2018-12-13 19:27:25.1  Retail
# 0        2018-01-09 15:05:01  Retail
# 1        2018-10-14 15:26:42  Retail
# 2        2018-02-20 17:23:06  Retail
# 3        2018-11-20 20:24:21  Retail
# 4        2018-11-12 16:26:20  Retail
# ...                      ...     ...
# 147415   2019-06-14 13:30:44  Retail
# 147416   2019-06-03 11:05:18  Retail
# 147417   2019-06-03 11:05:18  Retail
# 147418   2019-06-03 11:05:18  Retail
# 147419   2018-04-07 11:57:23  Retail
#
# [147420 rows x 14 columns]

# %%
### Generate transactions
nb_transactions = 10000
customers_range = (0,50)
items_range= (0,100)
stations_range = (0,100)
date_min = datetime(2017,1,1)
max_days = 356
res = []
for i in range(0,nb_transactions):
    res.append((
        randint(*items_range),
        randint(*customers_range),
        randint(*stations_range),
        (date_min + timedelta(days=randint(10,max_days))),
        i,
    ))
transactions = pd.DataFrame(res,columns=TRANSACTIONS_TABLE_FIELDS)
transactions["transaction_date"] = pd.to_datetime(transactions["transaction_date"])
transactions.to_sql("transactions",con=engine,if_exists="replace",index=False,method="multi",chunksize=2000)

# %%
transactions
# Out:
#       item_id  customer_id  station_id transaction_date  transaction_id
# 0          28           39          74       2017-07-08               0
# 1          10           10          68       2017-05-10               1
# 2           9           31          78       2017-09-09               2
# 3          95           25          99       2017-10-24               3
# 4          97           18          81       2017-12-12               4
# ...       ...          ...         ...              ...             ...
# 9995       22            0          16       2017-12-02            9995
# 9996       81           24          72       2017-01-13            9996
# 9997       44           18          91       2017-09-01            9997
# 9998       92           10          80       2017-04-15            9998
# 9999        4            1           1       2017-07-14            9999
#
# [10000 rows x 5 columns]

# %%
###### Insertion of customers
sex_values = ["M","F"]
age_values = ["<35","35-49",">49"]
departements_values = [i for i in range(0,98)]
res = []
for i in transactions.customer_id.unique():
    res.append((
        i,
        choice(sex_values),
        choice(age_values),
        choice(departements_values)
    ))
customers = pd.DataFrame(res,columns=CUSTOMERS_TABLE_FIELDS)
customers.to_sql("customers",con=engine,if_exists="replace",index=False)

# %%
### Insertion of items
items_columns = ["description","item_id"]
res = []
for i in transactions.item_id.unique():
    res.append((
        f"I-{i}",
        i,
    ))
items_df = pd.DataFrame(res,columns=ITEMS_TABLE_FIELDS)
items_df.to_sql('items',con=engine,if_exists="replace",index=False)

# %%
#### Insertion of stations
stations_columns = ["station_id","station_type"]
res = []
for i in transactions.station_id.unique():
    res.append((
        i,
        f"TYPE-{i%3}"
    ))
stations = pd.DataFrame(res,columns=stations_columns)
stations.to_sql("stations",con=engine,if_exists="replace",index=False)
